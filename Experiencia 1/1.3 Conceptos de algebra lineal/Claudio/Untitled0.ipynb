# %%
a = 2
b = 4.8
c = 7.435

print(a)
print(b)
print(c)


print(a+b)
print(b-c)
print(b*a)
print(c/b)
print(c//b)
#EXPERIMENTANDO CON ESCALARES
# Out:
# 2
# 4.8
# 7.435
# 6.8
# -2.635
# 9.6
# 1.5489583333333332
# 1.0

# %%
import numpy as np
v=np.array([8,0,3,1,5])
print(v)
#CREANDO UN VECTOR CON 5 ELEMENTOS
# Out:
# [8 0 3 1 5]

# %%
a=np.array([[5,4,7],
            [3,8,1]])
print(a.shape)
#CREANDO MATRIZ DE 2X3
# Out:
# (2, 3)
